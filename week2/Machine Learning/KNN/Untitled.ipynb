# %% [markdown]
# ## K-Nearest Neighbors (KNN)
#
# KNN is a simple supervised learning algorithm used for classification
# and regression. It works on the idea that **similar things exist close
# to each other** — a new data point is classified based on the majority
# class of its nearest neighbors.
#
# ### Algorithm Steps
# 1. Choose the number of neighbors, **K**
# 2. Calculate the distance (usually Euclidean) between the new point and all training points
# 3. Select the **K closest points** (nearest neighbors)
# 4. **Classification:** assign the majority class among the K neighbors
#    **Regression:** take the average value of the K neighbors
# 5. Return the predicted class/value
#
# ### Key Notes
# - **Lazy learner** — no real training phase, computation happens at prediction time
# - **Feature scaling is required** — since it's distance-based, always apply StandardScaler/MinMaxScaler first
# - **Choosing K matters:**
#   - Small K → sensitive to noise, overfits
#   - Large K → smoother decision boundary, may underfit
# - Slow on large datasets since it checks distance to every training point
#
# ### Visual Idea
#
#         Class A (●)         Class B (■)
#            ●   ●                ■   ■
#          ●   ●                ■   ■
#            ●   ●     ★?          ■   ■
#                    (new point)
#
# The new point (★) looks at its K nearest neighbors.
# If most nearby points are ● → classified as Class A
# If most nearby points are ■ → classified as Class B
