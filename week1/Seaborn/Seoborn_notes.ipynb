# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('iris.data')
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.columns = ['sepal_length', 'sepal_width','petal_length','petal_width','class']
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.displot(df.sepal_length)
plt.show()

# %%
sns.histplot(df.sepal_width)
plt.show()

# %%
df.sepal_length.value_counts()
# Out:
# sepal_length
# 5.0    10
# 6.3     9
# 6.7     8
# 5.1     8
# 5.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 5.6     6
# 5.4     6
# 6.1     6
# 6.0     6
# 4.9     6
# 6.5     5
# 4.8     5
# 6.2     4
# 7.7     4
# 6.9     4
# 5.2     4
# 4.6     4
# 4.4     3
# 5.9     3
# 7.2     3
# 6.8     3
# 4.7     2
# 6.6     2
# 4.3     1
# 7.0     1
# 4.5     1
# 7.1     1
# 7.6     1
# 7.3     1
# 5.3     1
# 7.4     1
# 7.9     1
# Name: count, dtype: int64

# %%
sns.kdeplot(df.petal_length,fill=True,color='gold',edgecolor='g',hatch='')
plt.show()

# %%
sns.swarmplot(df.petal_length)
# Out:
# <Axes: ylabel='petal_length'>

# %%
sns.histplot(df.sepal_width,fill=False,color='g',hatch='///')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
sns.displot(df.sepal_length[df['class']=='Iris-setosa'])
sns.displot(df.sepal_length[df['class']=='Iris-versicolor'])
sns.displot(df.sepal_length[df['class']=='Iris-virginica'])
plt.show()

# %%
sns.histplot(df.sepal_length[df['class']=='Iris-setosa'])
sns.histplot(df.sepal_length[df['class']=='Iris-versicolor'])
sns.histplot(df.sepal_length[df['class']=='Iris-virginica'])
plt.show()

# %%
sns.boxenplot(df.sepal_width)
plt.show()

# %%
sns.boxplot(x=df['class'],y=df.sepal_width)
plt.show()

# %%
sns.boxplot(x=df['class'],y=df.sepal_length,hue=df['class'],palette='bright')
plt.show()

# %%
# Boxenplot
sns.boxenplot(x=df['class'],y=df.sepal_length,palette='bright')
# Out:
# <Axes: xlabel='class', ylabel='sepal_length'>

# %%
sns.boxenplot(df.sepal_length)
plt.show()

# %%
np.percentile(df.sepal_length,6.25)
# Out:
# np.float64(4.7)

# %%
sns.violinplot(y=df.sepal_length,x=df['class'],palette='crest')
plt.show()

# %%
sns.stripplot(y=df.sepal_length,x=df['class'])
plt.show()

# %%
sns.swarmplot(y=df.sepal_length,x=df['class'],palette='dark')
plt.show()

# %%
sns.barplot(y=df.sepal_length,x=df['class'],palette='dark')
# Out:
# <Axes: xlabel='class', ylabel='sepal_length'>

# %%
sns.pointplot(y=df.sepal_length,x=df['class'])
plt.show()

# %%
sns.pointplot(y=df.sepal_length,x=df['class'],hue=df['class'])
plt.show()

# %%
sns.scatterplot(x=df['class'], y =df.sepal_length)
plt.show()

# %%
sns.scatterplot(x=df.sepal_length,y=df.petal_length,hue=df['class'])
plt.show()

# %%
sns.jointplot(x=df.sepal_length,y=df.sepal_width,hue=df['class'])
plt.show()

# %%
sns.jointplot(data=df)
plt.show()

# %%
sns.jointplot(data=df,kind='kde',fill=True)
plt.show()

# %%
sns.countplot(x=df['class'])
plt.show()

# %%
sns.countplot(x=df['sepal_length'])
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.countplot(x=df.sepal_length,palette='cool')
plt.show()

# %%
sns.pairplot(df,hue='class')
plt.show()

# %%
print(df.corr)
# Out:
# <bound method DataFrame.corr of      sepal_length  sepal_width  petal_length  petal_width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]>

# %%
df2 = df.drop('class',axis=1)
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.9          3.0           1.4          0.2
# 1           4.7          3.2           1.3          0.2
# 2           4.6          3.1           1.5          0.2
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4

# %%
c = df2.corr()
c
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.103784      0.871283     0.816971
# sepal_width      -0.103784     1.000000     -0.415218    -0.350733
# petal_length      0.871283    -0.415218      1.000000     0.962314
# petal_width       0.816971    -0.350733      0.962314     1.000000

# %%
sns.heatmap(c,annot=c)
plt.show()
