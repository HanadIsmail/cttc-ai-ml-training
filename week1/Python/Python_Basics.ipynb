# %% [markdown]
# # Python Basics

# %%
print("Hello world")
# Out:
# Hello world

# %%
#Keywords : 
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
#identifier : it is a name which is used to identify wheather its a class, function, object , variable etc.

# %% [markdown]
# ## Variable naming Rule :
# - Variable : it act as container which contains some values for future use.
# * We can not use Keywords as a variable Name
# * we can not use digits in the start of variable name
# * We can not use any special symbols inside a variable name Except (_ underscore)
# * we can not use space in between a variable name instead we can use underscore.

# %%
# variable: 
var = 19

# %% [markdown]
# # Data Types In Python
# - Data types divided into two types
#    - Primary :
#      1. Numeric: (int, float , complex)
#      2. Boolean : (bool , True, False)
#    - Sequential :
#      * String (strt)
#      * List (list)
#      * Tuple (tuple)
#      * Set
#      * Dictionary
# -

# %% [markdown]
# ### 1 . Integer (int)

# %%
a = 12
type(a)
# Out:
# int

# %% [markdown]
# ### 2 . Float

# %%
a1 = 15.8
type(a1)
# Out:
# float

# %% [markdown]
# ### 3. Complex

# %%
a2 = 6+5j
type(a2)
# Out:
# complex

# %% [markdown]
# ### 4. Boolean(bool)

# %%
a3 = False
type(a3)
# Out:
# bool

# %% [markdown]
# ### 5. String (str)

# %%
b = "apple"
type(b)
# Out:
# str

# %%
# Multiple Line String
s = """ Hello everyone,
welcome to CTTC. """
print(s)
# Out:
#  Hello everyone,
# welcome to CTTC.

# %% [markdown]
# ### 6. list :
# + List is a sequence of items stored in square braces and sepered with coma, its beautable and ordered
# + it can support homogeneous and heterogeneous data type.

# %%
# List : 
l = [23, 19.5, True, 5+12j]
type(l)
# Out:
# list

# %% [markdown]
# ### 7. Tuple :
# * Tuple : its a sequence of elements or items stored inside a parenthesis and seperated with coma .
# - its ordered and immutable
# - it can support homogeneous and heterogeneous data type

# %%
# Tuple
t = (23, 19.5, True, 5+12j)

# %% [markdown]
# ### 8. Set
# * set : is a sequence of elements  stored inside a curly braces and saperated with coma
# - its unordered and mutable
# - it can support homo and hetero
# - it gives unique values or unique elements no duplicates

# %%
# set 
s = {39,20,19, 14.3, 19, False}
s
# Out:
# {False, 14.3, 19, 20, 39}

# %% [markdown]
# ### 9. Dictionary (dict)
# - Dictionary it is a sequence of paired elements stored inside a curly bracket and saperated with coma
# - its ordered and mutable
# - it can support homo and heterogeneous datatype
# - Each pair Element consist of one Key and one value which is saperated in colon(:)

# %%
# dictionary
d = { 'name': 'Hanad', 'Rollno': '2447018', 'age' : '21'}
d
# Out:
# {'name': 'Hanad', 'Rollno': '2447018', 'age': '21'}

# %%
type(d)
# Out:
# dict

# %% [markdown]
# #### Indexing

# %%
# String Indexing
s = 'Apple'
s[2]
# Out:
# 'p'

# %%
s[-1]
# Out:
# 'e'

# %% [markdown]
# #### Slicing
# - Slicing Syntax : Var [  start_index : Stop_index +1 : step  ]

# %%
s = 'Apple'

s[1:3:1]
# Out:
# 'pp'

# %%
# 1st "pe"
s[1:5:3]
# Out:
# 'pe'

# %% [markdown]
# * Syntax of backeard Slicing : var [ start : stop -1 : -step ]

# %%
#el
s[-1 : -3: -1 ]
# Out:
# 'el'

# %%
# Reverse
s[-1:-6:-1]
# Out:
# 'elppA'

# %%
s[::-1]
# Out:
# 'elppA'

# %% [markdown]
# <h2/>Day 2 of python Basics <h2/>

# %% [markdown]
# ### string Attributes

# %%
# string Attributes

s = "HelLo EvEryYone"
s
# Out:
# 'HelLo EvEryYone'

# %%
s.capitalize()
# Capitalize() converts first character into upper case and rest into lowercase
# Out:
# 'Hello everyyone'

# %%
s.upper()
# upper() : it converts all characters into uppercase
# Out:
# 'HELLO EVERYYONE'

# %%
s.lower()
# Out:
# 'hello everyyone'

# %%
s.title()
# title() : it converts all first character in each word into uppercase and rest lowercase
# Out:
# 'Hello Everyyone'

# %%
s.swapcase()
# swapcase() : it converts uppercase into lowercase and lowercase into uppercase
# Out:
# 'hELlO eVeRYyONE'

# %%
s.split()
#split() :  by default it will split when space encountred .
# Out:
# ['HelLo', 'EvEryYone']

# %%
'www.cctc.gov.in'.split('.')
# Out:
# ['www', 'cctc', 'gov', 'in']

# %%
s.index('v')
# it will return the index of the character assigned .
# Out:
# 7

# %%
s.count('E')
# Out:
# 2

# %%
'_'.join(('Nirmal' , 'kumar'))
# Out:
# 'Nirmal_kumar'

# %%
'abc'.isalpha()
# Out:
# True

# %%
'abc123'.isalnum()
# Out:
# True

# %%
'123'.isdigit()
# Out:
# True

# %%
'1234'.isnumeric()
# Out:
# True

# %% [markdown]
# ## List Attributes

# %%
l = [12 , 29.6, True]
l
# Out:
# [12, 29.6, True]

# %%
l.append('apple')
l
# it will add into the list
# Out:
# [12, 29.6, True, 'apple']

# %%
l.insert(3,35.7)
l
# Out:
# [12, 29.6, True, 35.7, 'apple']

# %%
m = [67, 89, 14]
m.extend(l)
m
# Out:
# [67, 89, 14, 12, 29.6, True, 35.7, 'apple']

# %%
m.count(12)
# Out:
# 1

# %%
m.pop()
m
# pop() : it will remove the last element in the list
# Out:
# [67, 89, 14, 12, 29.6, True, 35.7]

# %%
m.remove(12)
m
# Out:
# [67, 89, 14, 29.6, True, 35.7]

# %%
m.clear()
m
# Out:
# []

# %%
n = [19, 12, 34, 14, 23, 29 ] 
n.sort()
n
# sort() : it will return values in ascending order
# Out:
# [12, 14, 19, 23, 29, 34]

# %%
n.reverse()
n
# Out:
# [34, 29, 23, 19, 14, 12]

# %%
m.sort(reverse=True)
m
# Out:
# []

# %% [markdown]
# ## Tuple Attributes :

# %%
t = (28,10,36,92,True)
t
# Out:
# (28, 10, 36, 92, True)

# %%
t.index(36)
# Out:
# 2

# %%
t.count(10)
# Out:
# 1

# %%
t[2::1]
# Out:
# (36, 92, True)

# %% [markdown]
# ## Set Attributes :

# %%
s = {12 , 9 , 18, 93,28, True, 70.6, 12, 9,9}
s
# Out:
# {True, 9, 12, 18, 28, 70.6, 93}

# %%
a = {1,3,2,4} 
b = {3,4,7,6}

print('a = ', a)
print('b = ', b)
# Out:
# a =  {1, 2, 3, 4}
# b =  {3, 4, 6, 7}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 6, 7}

# %%
a.intersection(b)
# it will return common elements in a and b
# Out:
# {3, 4}

# %%
b.difference(a)
# Out:
# {6, 7}

# %%
a.issubset(b)
# Out:
# False

# %%
a.issuperset(b)
# Out:
# False

# %%
a.isdisjoint(b)
# if there is no common value then it will return True
# Out:
# False

# %%
a.add(35)
a
# Out:
# {1, 2, 3, 4, 35}

# %%
a.discard(32)
a
# Out:
# {1, 2, 3, 4, 35}

# %%
a.clear()
a
# Out:
# set()

# %% [markdown]
# ## Dictionary Attributes :

# %%
d = { 'name': 'Hanad', 'Course': 'AI/ML', 'Age' : '21'} 
d
# Out:
# {'name': 'Hanad', 'Course': 'AI/ML', 'Age': '21'}

# %%
d.update({'Roll' : 25})
d
# Out:
# {'name': 'Hanad', 'Course': 'AI/ML', 'Age': '21', 'Roll': 25}

# %%
d.update({'name' : 'ismail'})
d
# Out:
# {'name': 'ismail', 'Course': 'AI/ML', 'Age': '21', 'Roll': 25}

# %%
d.keys()
# Out:
# dict_keys(['name', 'Course', 'Age', 'Roll'])

# %%
d.values()
# Out:
# dict_values(['ismail', 'AI/ML', '21', 25])

# %%
d.items()
# Out:
# dict_items([('name', 'ismail'), ('Course', 'AI/ML'), ('Age', '21'), ('Roll', 25)])

# %%
d.get('name')
# Out:
# 'ismail'

# %%
d.pop('Age')
d
# Out:
# {'name': 'ismail', 'Course': 'AI/ML', 'Roll': 25}

# %%
d.popitem()
d
# popitem() : will remove last element in the dictionary
# Out:
# {'name': 'ismail'}

# %%
d.clear()

# %% [markdown]
# ## Operators In Python
# - #### Types of Operators
#   + Arithmetic Operators : ( + , - , * , / , % , // , ** )
#   + Assignment Operators : ( = , +=, -= , *= , /= ,%= , //=, **= )
#   + Relational Operators : ( < , > , <=, >=, ==, != )
#   + Logical Operators : ( ' and' , 'or' , and 'not' )
#   + Identity Operators : ( ' is ' ,' is not ' )
#   + Membership Operators : ( 'in' , 'not in' )
#   + String Operator : ( '+' for concatenation , '*' for string Multiplication )

# %%
a = 13
b = 3 
a,b
# Out:
# (13, 3)

# %% [markdown]
# #### Arithmetic Operators : ( + , - , * , / , % , // , ** ) :

# %%
print('a + b =  ', a+b)
print('a - b =  ', a-b)
print('a * b =  ', a*b)
print('a / b =  ', a/b)
print('a % b =  ', a%b)
print('a // b =  ', a//b)
print('a ** b =  ', a**b)
# Out:
# a + b =   16
# a - b =   10
# a * b =   39
# a / b =   4.333333333333333
# a % b =   1
# a // b =   4
# a ** b =   2197

# %%
6!=10
# Out:
# True

# %%
not 6!=10
# Out:
# False

# %%
## Identity Operators : ( ' is ' ,' is not ' )
a = 5 
b = 5
a is b
# Out:
# True

# %%
n = 500
m = 500
m is n
# Out:
# False

# %%
print(id(a))
print(id(b))
# Out:
# 140730959111208
# 140730959111208

# %%
print(id(m))
print(id(n))
# Out:
# 3025345144432
# 3025345150288

# %%
# memberships operator
a = [14, 27, 19, 2, 56 ]
56 in a
# Out:
# True

# %%
7 not in a
# Out:
# True

# %% [markdown]
# ### Input Function

# %%
input('Enter you name')
# Out:
# Enter you name hanad
# 'hanad'

# %%
a = input("Enter 1st number : ")
b = input("Enter 2st number : ")

print("a + b = ", a+b)
# Out:
# Enter 1st number :  20
# Enter 2st number :  2
# a + b =  202

# %%
# it just combine the value of a and b because by dafault input in str
type(a)
# Out:
# str

# %%
# Type casting
n = 13
type(n)
# Out:
# int

# %%
a = int(input("Enter 1st number : "))
b = int(input("Enter 2st number : "))

print("a + b = ", a+b)
# Out:
# Enter 1st number :  10
# Enter 2st number :  20
# a + b =  30
